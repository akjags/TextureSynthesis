# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weights = np.load('tmp/model_weights.npy').item()
print weights['conv1_2'].shape
print weights.keys()
# Out:
# (3, 3, 64, 64)
# ['conv5_4', 'conv5_1', 'conv5_3', 'conv5_2', 'conv4_4', 'conv4_1', 'conv4_2', 'conv4_3', 'conv3_4', 'conv3_3', 'conv3_2', 'conv3_1', 'conv1_1', 'conv1_2', 'conv2_2', 'conv2_1']

# %%
c

# %%
fig = plt.figure(figsize=(15, 20))
sns.set_style('dark')
sns.color_palette('hot')
for i in range(64):
    ax1 = fig.add_subplot(8,8,i)
    ax1.imshow(weights['conv1_1'][:,:,:,i])
    ax1.xaxis.set_ticklabels([])
    ax1.yaxis.set_ticklabels([])
